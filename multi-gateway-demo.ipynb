# %%
# !wget https://ws-assets-prod-iad-r-iad-ed304a55c2ca1aee.s3.us-east-1.amazonaws.com/508f04dc-026a-4260-ac15-c6f011d50cf9/agentcore-multi-target-gateway-starter-code.zip
# !unzip -o agentcore-multi-target-gateway-starter-code.zip
# !ls -la
# Out:
# --2025-11-01 11:06:51--  https://ws-assets-prod-iad-r-iad-ed304a55c2ca1aee.s3.us-east-1.amazonaws.com/508f04dc-026a-4260-ac15-c6f011d50cf9/agentcore-multi-target-gateway-starter-code.zip
# Resolving ws-assets-prod-iad-r-iad-ed304a55c2ca1aee.s3.us-east-1.amazonaws.com (ws-assets-prod-iad-r-iad-ed304a55c2ca1aee.s3.us-east-1.amazonaws.com)... 16.15.216.55, 52.216.207.150, 3.5.12.206, ...
# Connecting to ws-assets-prod-iad-r-iad-ed304a55c2ca1aee.s3.us-east-1.amazonaws.com (ws-assets-prod-iad-r-iad-ed304a55c2ca1aee.s3.us-east-1.amazonaws.com)|16.15.216.55|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45432 (44K) [application/zip]
# Saving to: ‘agentcore-multi-target-gateway-starter-code.zip’
#
# agentcore-multi-tar 100%[===================>]  44.37K  --.-KB/s    in 0.001s
#
# 2025-11-01 11:06:51 (54.3 MB/s) - ‘agentcore-multi-target-gateway-starter-code.zip’ saved [45432/45432]
#
# Archive:  agentcore-multi-target-gateway-starter-code.zip
#    creating: agentcore-gateway-starter-code/
#   inflating: agentcore-gateway-starter-code/single-target-gateway.ipynb
#   inflating: agentcore-gateway-starter-code/requirements.txt
#   inflating: agentcore-gateway-starter-code/create_lambda_zips.py
#   inflating: agentcore-gateway-starter-code/multi-target-gateway.ipynb
#   inflating: agentcore-gateway-starter-code/utils.py
#   inflating: agentcore-gateway-starter-code/smo_planner_extended.py
#    creating: agentcore-gateway-starter-code/lambda_zips/
#   inflating: agentcore-gateway-starter-code/lambda_zips/configure_slice_parameters.zip
#   inflating: agentcore-gateway-starter-code/lambda_zips/create_v2x_handover_plan.zip
#   inflating: agentcore-gateway-starter-code/lambda_zips/create_energy_saving_plan.zip
#   inflating: agentcore-gateway-starter-code/lambda_zips/create_mimo_optimization_plan.zip
#   inflating: agentcore-gateway-starter-code/lambda_zips/create_uav_resource_plan.zip
#   inflating: agentcore-gateway-starter-code/lambda_zips/execute_energy_optimization.zip
#   inflating: agentcore-gateway-starter-code/lambda_zips/execute_mimo_optimization.zip
#   inflating: agentcore-gateway-starter-code/lambda_zips/execute_v2x_handover_optimization.zip
#   inflating: agentcore-gateway-starter-code/lambda_zips/deploy_a1_policy.zip
#   inflating: agentcore-gateway-starter-code/lambda_zips/execute_uav_resource_allocation.zip
# total 344
# drwx------. 15 sagemaker-user nogroup  4096 Nov  1 11:06 .
# drwxrwxrwx.  1 root           root       28 Aug 17 00:29 ..
# -rw-rw-rw-.  1 nobody         nogroup     5 Nov  1 10:17 .bashrc
# -rw-r--r--.  1 sagemaker-user users    5458 Nov  1 11:06 .bedrock_agentcore.yaml
# drwxr-xr-x.  5 sagemaker-user users      41 Nov  1 10:26 .cache
# drwxr-xr-x.  3 sagemaker-user users      24 Nov  1 10:24 .config
# -rw-r--r--.  1 sagemaker-user users     691 Nov  1 10:47 .dockerignore
# drwxr-xr-x.  8 sagemaker-user users     185 Nov  1 11:06 .git
# -rw-r--r--.  1 sagemaker-user users      63 Nov  1 10:34 .gitconfig
# -rw-r--r--.  1 sagemaker-user users     220 Nov  1 11:00 .gitignore
# drwxr-xr-x.  2 sagemaker-user users    4096 Nov  1 11:06 .ipynb_checkpoints
# drwxr-xr-x.  3 sagemaker-user users      29 Nov  1 10:24 .ipython
# drwxr-xr-x.  4 sagemaker-user users      37 Nov  1 10:26 .jupyter
# -rw-------.  1 sagemaker-user users      20 Nov  1 10:45 .lesshst
# drwxr-xr-x.  3 sagemaker-user users      19 Nov  1 10:17 .local
# drwxr-xr-x.  3 sagemaker-user users      19 Nov  1 10:17 .npm
# drwxr-xr-x.  2 sagemaker-user users      62 Nov  1 10:17 .sagemaker_sql_editor_api_cache
# drwx------.  2 sagemaker-user users      88 Nov  1 10:34 .ssh
# drwxr-xr-x.  2 sagemaker-user users     113 Nov  1 11:00 .virtual_documents
# -rw-r--r--.  1 sagemaker-user users     774 Nov  1 11:05 Dockerfile
# -rw-r--r--.  1 sagemaker-user users      62 Nov  1 10:33 README.md
# drwxr-xr-x.  2 sagemaker-user users      43 Nov  1 10:47 __pycache__
# -rw-r--r--.  1 sagemaker-user users    5264 Oct 21 14:58 agent.py
# drwx------.  3 sagemaker-user users    4096 Oct  6 20:16 agentcore-gateway-starter-code
# -rw-r--r--.  1 sagemaker-user users   45432 Oct 24 16:42 agentcore-multi-target-gateway-starter-code.zip
# -rw-r--r--.  1 sagemaker-user users    9325 Oct 21 14:58 cognito_utils.py
# -rw-r--r--.  1 sagemaker-user users    3188 Oct 21 14:58 deploy_strands_agent.py
# -rw-r--r--.  1 sagemaker-user users   42727 Nov  1 11:05 download-notebook.ipynb
# -rw-r--r--.  1 sagemaker-user users    3525 Nov  1 10:55 invoke_mcp_tools.py
# -rw-r--r--.  1 sagemaker-user users   12003 Nov  1 10:53 mcp_server.py
# -rw-r--r--.  1 sagemaker-user users    9498 Oct 21 14:58 memory_agent.py
# -rw-r--r--.  1 sagemaker-user users      72 Nov  1 11:06 multi-gateway-demo.ipynb
# -rw-r--r--.  1 sagemaker-user users     705 Nov  1 10:53 my_mcp_client.py
# -rw-r--r--.  1 sagemaker-user users    3558 Nov  1 10:55 my_mcp_client_remote.py
# -rw-r--r--.  1 sagemaker-user users   65643 Nov  1 10:55 o2-mcp-server.ipynb
# -rw-r--r--.  1 sagemaker-user users   63167 Nov  1 10:50 r1-mcp-server.ipynb
# -rw-r--r--.  1 sagemaker-user users     174 Oct 21 14:58 requirements.txt
# -rw-r--r--.  1 sagemaker-user users    2145 Oct 21 14:58 test_agent.py
# lrwxrwxrwx.  1 nobody         nogroup    72 Nov  1 10:17 user-default-efs -> /mnt/custom-file-systems/efs/fs-0fe1895bd9b375057_fsap-0a903e9005c751931
